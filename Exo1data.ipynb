# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb


df = pd.read_csv('house_pricing.csv')
df.head()
df.info
filtre1 = df[df.LotArea<20000][df.SalePrice<500000]
sb.relplot(x='LotArea', y='SalePrice',data=filtre1)
df.plot.scatter(x='LotFrontage',y='LotArea')
# Out:
# C:\Users\valen\anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # Remove the CWD from sys.path while we load stuff.
